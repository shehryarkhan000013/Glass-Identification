# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Naeem Ahmed\Downloads\fbc3fc9443121d1fb55b299da2e88490-23aad569a2c1d91ddcd536981150a8dd0971707b\fbc3fc9443121d1fb55b299da2e88490-23aad569a2c1d91ddcd536981150a8dd0971707b\glass.csv")

# %%
df
# Out:
#      Unnamed: 0       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0             1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1             2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2             3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3             4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4             5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..          ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209         210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210         211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211         212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212         213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213         214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ...

# %%
df=df.drop("Unnamed: 0", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
c=df.corr()

# %%
c
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(c,cmap='coolwarm')
plt.show()

# %%
X=df.drop('Type', axis=1)

# %%
X
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
y=df['Type']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
y.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Type'>

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train, y_test= train_test_split(X,y, test_size=0.3, random_state=42)

# %%
x_train
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
# 137  1.51711  12.89  3.62  1.57  72.96  0.61   8.11  0.00  0.00
# 65   1.52099  13.69  3.59  1.12  71.96  0.09   9.40  0.00  0.00
# 108  1.52222  14.43  0.00  1.00  72.67  0.10  11.52  0.00  0.08
# 181  1.51888  14.99  0.78  1.74  72.50  0.00   9.95  0.00  0.00
# 31   1.51747  12.84  3.50  1.14  73.27  0.56   8.55  0.00  0.00
# ..       ...    ...   ...   ...    ...   ...    ...   ...   ...
# 106  1.53125  10.73  0.00  2.10  69.81  0.58  13.30  3.15  0.28
# 14   1.51763  12.61  3.59  1.31  73.29  0.58   8.50  0.00  0.00
# 92   1.51588  13.12  3.41  1.58  73.26  0.07   8.39  0.00  0.19
# 179  1.51852  14.09  2.19  1.66  72.67  0.00   9.32  0.00  0.00
# 102  1.51820  12.62  2.76  0.83  73.81  0.35   9.42  0.00  0.20
#
# [149 rows x 9 columns]

# %%
x_train.shape
# Out:
# (149, 9)

# %%
y_train.shape
# Out:
# (149,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model1=DecisionTreeClassifier()
model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model1.predict(x_test)

# %%
pred
# Out:
# array([1, 7, 3, 7, 2, 2, 1, 2, 2, 3, 6, 5, 1, 2, 6, 5, 7, 1, 1, 2, 1, 7,
#        7, 7, 3, 2, 1, 1, 6, 1, 2, 2, 2, 2, 7, 7, 5, 3, 1, 1, 3, 7, 3, 1,
#        3, 2, 2, 2, 5, 2, 1, 1, 3, 2, 1, 2, 1, 1, 5, 3, 1, 2, 1, 7, 6],
#       dtype=int64)

# %%
from sklearn.metrics import accuracy_score as ac

# %%
accuracy=ac(pred,y_test)

# %%
accuracy
# Out:
# 0.676923076923077

# %%
from sklearn.metrics import classification_report
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.63      0.63      0.63        19
#            2       0.61      0.78      0.68        18
#            3       0.75      0.33      0.46         9
#            5       0.67      0.80      0.73         5
#            6       0.67      0.50      0.57         4
#            7       0.90      0.90      0.90        10
#
#     accuracy                           0.68        65
#    macro avg       0.70      0.66      0.66        65
# weighted avg       0.69      0.68      0.67        65

# %%
from sklearn import svm
model2=svm.SVC(C=10)
model2.fit(x_train,y_train)
pred2=model2.predict(x_test)
acc=ac(pred2,y_test)
print(acc)
# Out:
# 0.35384615384615387

# %%
from sklearn.ensemble import RandomForestClassifier
model3=RandomForestClassifier(n_estimators=100)

# %%
model3.fit(x_train,y_train)
pred3=model3.predict(x_test)
acc=ac(pred3,y_test)
print(acc)
# Out:
# 0.8153846153846154

# %%
inp=[[1.21711,2.89,1.62,2.02,63.96,1.61,6.11,1.00,0.00]]
x=model3.predict(inp)
print(x)
if x==2:
    print("Tabaii Category")
else:
    print("something is wrong")
# Out:
# [5]
# something is wrong
# C:\Users\Naeem Ahmed\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
